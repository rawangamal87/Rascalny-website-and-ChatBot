# %%
import pandas as pd 
import numpy as np

# %%
import json

with open(r'C:\Users\compumarts\Desktop\Chatbot\data.json', 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data['intents'])

# %%
pd.options.display.max_colwidth=None
df.head()
# Out:
#                              tag  \
# 0          أساسيات إعادة التدوير
# 1  المواد القابلة لإعادة التدوير
# 2            عملية إعادة التدوير
# 3            فوائد إعادة التدوير
# 4          إرشادات إعادة التدوير
#
#                                                                                                                                                                 patterns  \
# 0                                                               [ما هي إعادة التدوير؟, كيف تعمل إعادة التدوير؟, اخبرني عن إعادة التدوير, لماذا يجب علينا إعادة التدوير؟]
# 1                         [ما هي المواد التي يمكن إعادة تدويرها؟, ما هي المواد القابلة لإعادة التدوير؟, هل يمكنني إعادة تدوير البلاستيك؟, هل يمكنني إعادة تدوير الزجاج؟]
# 2                                       [كيف يتم إعادة تدوير البلاستيك؟, ماذا يحدث للورق بعد إعادة التدوير؟, اخبرني عن عملية إعادة التدوير, كيف يتم إعادة تدوير الزجاج؟]
# 3                                             [ما هي فوائد إعادة التدوير؟, لماذا تعتبر إعادة التدوير مهمة؟, كيف تساعد إعادة التدوير البيئة؟, ما هو تأثير إعادة التدوير؟]
# 4  [كيف أتمكن من إعادة التدوير بشكل صحيح؟, ما هي قواعد إعادة التدوير؟, هل هناك أي إرشادات لإعادة التدوير يجب أن أعرفها؟, كيف يجب أن أفرز المواد القابلة لإعادة التدوير؟]
#
#                                                                                                                                                                                                                                                                                                                                  responses
# 0  [إعادة التدوير هي عملية تحويل المواد التالفة إلى منتجات جديدة للحد من هدر المواد التي يمكن استخدامها., إعادة التدوير تساعد في الحفاظ على الموارد الطبيعية، وتقليل التلوث، وتوفير الطاقة من خلال إعادة استخدام المواد الخام., نقوم بإعادة التدوير للحد من التأثير البيئي للنفايات، والحفاظ على الموارد الطبيعية، وتقليل استهلاك الطاقة.]
# 1                                                       [المواد القابلة لإعادة التدوير تشمل الورق، الكرتون، الزجاج، البلاستيك، والمعادن., يمكنك إعادة تدوير معظم أنواع البلاستيك، والزجاجات الزجاجية، وعلب الألومنيوم، ومنتجات الورق., ليس كل أنواع البلاستيك قابلة لإعادة التدوير. تحقق من برنامج إعادة التدوير المحلي لمعرفة الإرشادات.]
# 2                                       [إعادة تدوير البلاستيك تتضمن تنظيفه، وذوبانه، وإعادة تشكيله إلى منتجات جديدة., بعد إعادة تدوير الورق، يتم تكسير الورق إلى ألياف، ثم تنظيفه، وتحويله إلى منتجات ورقية جديدة., يتم سحق الزجاج، وذوبانه، ثم صبه في قوالب لإنتاج منتجات زجاجية جديدة. يمكن إعادة تدوير الزجاج بلا حدود من حيث الجودة.]
# 3                   [إعادة التدوير تساعد في توفير الطاقة، وتقليل التلوث، والحفاظ على الموارد الطبيعية، مما يساهم في بيئة صحية., من خلال إعادة التدوير، نقلل الحاجة إلى المواد الخام، ونقلل انبعاثات الغازات الدفيئة، ونوفر الطاقة., إعادة التدوير تقلل من النفايات في المدافن وتساعد في مكافحة المشاكل البيئية مثل إزالة الغابات والتلوث.]
# 4         [يجب فرز المواد المختلفة في صناديق منفصلة. تأكد من أن المواد نظيفة وخالية من الملوثات قبل إعادة التدوير., تحقق من برنامج إعادة التدوير المحلي للحصول على إرشادات محددة، حيث قد تختلف القواعد حسب الموقع., تجنب وضع مواد مثل الأكياس البلاستيكية، وبقايا الطعام، أو البلاستيك غير القابل لإعادة التدوير في صناديق إعادة التدوير.]

# %%
dic = {"tag":[], "patterns":[], "responses":[]}
for example in data['intents']:
    for pattern in example['patterns']:
        dic['patterns'].append(pattern)
        dic['tag'].append(example['tag'])
        dic['responses'].append(example['responses'])

# %%
pd.options.display.max_colwidth=15
df = pd.DataFrame.from_dict(dic)
df
# Out:
#                tag        patterns       responses
# 0   أساسيات إعا...  ما هي إعادة...  [إعادة التد...
# 1   أساسيات إعا...  كيف تعمل إع...  [إعادة التد...
# 2   أساسيات إعا...  اخبرني عن إ...  [إعادة التد...
# 3   أساسيات إعا...  لماذا يجب ع...  [إعادة التد...
# 4   المواد القا...  ما هي الموا...  [المواد الق...
# 5   المواد القا...  ما هي الموا...  [المواد الق...
# 6   المواد القا...  هل يمكنني إ...  [المواد الق...
# 7   المواد القا...  هل يمكنني إ...  [المواد الق...
# 8   عملية إعادة...  كيف يتم إعا...  [إعادة تدوي...
# 9   عملية إعادة...  ماذا يحدث ل...  [إعادة تدوي...
# 10  عملية إعادة...  اخبرني عن ع...  [إعادة تدوي...
# 11  عملية إعادة...  كيف يتم إعا...  [إعادة تدوي...
# 12  فوائد إعادة...  ما هي فوائد...  [إعادة التد...
# 13  فوائد إعادة...  لماذا تعتبر...  [إعادة التد...
# 14  فوائد إعادة...  كيف تساعد إ...  [إعادة التد...
# 15  فوائد إعادة...  ما هو تأثير...  [إعادة التد...
# 16  إرشادات إعا...  كيف أتمكن م...  [يجب فرز ال...
# 17  إرشادات إعا...  ما هي قواعد...  [يجب فرز ال...
# 18  إرشادات إعا...  هل هناك أي ...  [يجب فرز ال...
# 19  إرشادات إعا...  كيف يجب أن ...  [يجب فرز ال...
# 20  أماكن إعادة...  أين يمكنني ...  [يمكنك العث...
# 21  أماكن إعادة...  أين يمكنني ...  [يمكنك العث...
# 22  أماكن إعادة...  هل هناك مرك...  [يمكنك العث...
# 23  أماكن إعادة...  كيف يمكنني ...  [يمكنك العث...
# 24  العناصر غير...  ما الذي لا ...  [العناصر مث...
# 25  العناصر غير...  هل يمكن إعا...  [العناصر مث...
# 26  العناصر غير...  هل يمكنني إ...  [العناصر مث...
# 27  العناصر غير...  ماذا عن الس...  [العناصر مث...
# 28  Recycling B...  What is rec...  [Recycling ...
# 29  Recycling B...  How does re...  [Recycling ...
# 30  Recycling B...  Tell me abo...  [Recycling ...
# 31  Recycling B...  Why should ...  [Recycling ...
# 32  Recycling M...  What can be...  [Commonly r...
# 33  Recycling M...  What materi...  [Commonly r...
# 34  Recycling M...  Can I recyc...  [Commonly r...
# 35  Recycling M...  Can I recyc...  [Commonly r...
# 36  Recycling P...  How is plas...  [Plastic re...
# 37  Recycling P...  What happen...  [Plastic re...
# 38  Recycling P...  Tell me abo...  [Plastic re...
# 39  Recycling P...  How do they...  [Plastic re...
# 40  Recycling B...  What are th...  [Recycling ...
# 41  Recycling B...  Why is recy...  [Recycling ...
# 42  Recycling B...  How does re...  [Recycling ...
# 43  Recycling B...  What impact...  [Recycling ...
# 44  Recycling G...  How do I re...  [Different ...
# 45  Recycling G...  What are th...  [Different ...
# 46  Recycling G...  Are there a...  [Different ...
# 47  Recycling G...  How should ...  [Different ...
# 48  Recycling L...  Where can I...  [You can fi...
# 49  Recycling L...  Where do I ...  [You can fi...
# 50  Recycling L...  Is there a ...  [You can fi...
# 51  Recycling L...  How can I f...  [You can fi...
# 52  Non-recycla...  What can't ...  [Items like...
# 53  Non-recycla...  Are pizza b...  [Items like...
# 54  Non-recycla...  Can I recyc...  [Items like...
# 55  Non-recycla...  What about ...  [Items like...

# %%
df['tag'].unique()
# Out:
# array(['أساسيات إعادة التدوير', 'المواد القابلة لإعادة التدوير',
#        'عملية إعادة التدوير', 'فوائد إعادة التدوير',
#        'إرشادات إعادة التدوير', 'أماكن إعادة التدوير',
#        'العناصر غير القابلة لإعادة التدوير', 'Recycling Basics',
#        'Recycling Materials', 'Recycling Process', 'Recycling Benefits',
#        'Recycling Guidelines', 'Recycling Locations',
#        'Non-recyclable Items'], dtype=object)

# %%
df['tag'].nunique()
# Out:
# 14

# %% [markdown]
# ## Data Preprocessing¶

# %% [markdown]
# ##### Now I am going to apply some text preprocessing stuffs such as lowering, punctuation removing and then tokenize the patterns.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(lower=True, split=' ')
#  lists to be a token 
tokenizer.fit_on_texts(df['patterns'])
# serialized JSON dictionary
tokenizer.get_config()
# Out:
# {'num_words': None,
#  'filters': '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
#  'lower': True,
#  'split': ' ',
#  'char_level': False,
#  'oov_token': None,
#  'document_count': 56,
#  'word_counts': '{"\\u0645\\u0627": 7, "\\u0647\\u064a": 5, "\\u0625\\u0639\\u0627\\u062f\\u0629": 21, "\\u0627\\u0644\\u062a\\u062f\\u0648\\u064a\\u0631\\u061f": 11, "\\u0643\\u064a\\u0641": 7, "\\u062a\\u0639\\u0645\\u0644": 1, "\\u0627\\u062e\\u0628\\u0631\\u0646\\u064a": 2, "\\u0639\\u0646": 3, "\\u0627\\u0644\\u062a\\u062f\\u0648\\u064a\\u0631": 8, "\\u0644\\u0645\\u0627\\u0630\\u0627": 2, "\\u064a\\u062c\\u0628": 3, "\\u0639\\u0644\\u064a\\u0646\\u0627": 1, "\\u0627\\u0644\\u0645\\u0648\\u0627\\u062f": 4, "\\u0627\\u0644\\u062a\\u064a": 1, "\\u064a\\u0645\\u0643\\u0646": 3, "\\u062a\\u062f\\u0648\\u064a\\u0631\\u0647\\u0627\\u061f": 1, "\\u0627\\u0644\\u0642\\u0627\\u0628\\u0644\\u0629": 3, "\\u0644\\u0625\\u0639\\u0627\\u062f\\u0629": 6, "\\u0647\\u0644": 6, "\\u064a\\u0645\\u0643\\u0646\\u0646\\u064a": 6, "\\u062a\\u062f\\u0648
0627\\u0630\\u0627": 37, "\\u0647\\u0646\\u0627\\u0643": 38, "\\u0623\\u0646": 39, "\\u0623\\u064a\\u0646": 40, "\\u0628\\u0627\\u0644\\u0642\\u0631\\u0628": 41, "\\u0645\\u0646\\u064a\\u061f": 42, "tell": 43, "why": 44, "be": 45, "recyclable": 46, "plastic": 47, "there": 48, "recyclables": 49, "where": 50, "near": 51, "\\u062a\\u0639\\u0645\\u0644": 52, "\\u0639\\u0644\\u064a\\u0646\\u0627": 53, "\\u0627\\u0644\\u062a\\u064a": 54, "\\u062a\\u062f\\u0648\\u064a\\u0631\\u0647\\u0627\\u061f": 55, "\\u064a\\u062d\\u062f\\u062b": 56, "\\u0644\\u0644\\u0648\\u0631\\u0642": 57, "\\u0628\\u0639\\u062f": 58, "\\u0639\\u0645\\u0644\\u064a\\u0629": 59, "\\u0641\\u0648\\u0627\\u0626\\u062f": 60, "\\u062a\\u0639\\u062a\\u0628\\u0631": 61, "\\u0645\\u0647\\u0645\\u0629\\u061f": 62, "\\u062a\\u0633\\u0627\\u0639\\u062f": 63, "\\u0627\\u0644\\u0628\\u064a\\u0626\\u0629\\u061f": 64, "\\u0647\\u0648": 65, "\\u062a\\u0623\\u062b\\u064a\\u0631": 66, "\\u0623\\u062a\\u0645\\u0643\\u0646": 67, "\\u0645\\u0646": 68, "\\u0628\\u0634\\u0643\\u0644": 69, "\\u0635\\u062d\\u064a\\u062d\\u061f": 70, "\\u0642\\u0648\\u0627\\u0639\\u062f": 71, "\\u0623\\u064a": 72, "\\u0625\\u0631\\u0634\\u0627\\u062f\\u0627\\u062a": 73, "\\u0623\\u0639\\u0631\\u0641\\u0647\\u0627\\u061f": 74, "\\u0623\\u0641\\u0631\\u0632": 75, "\\u062a\\u0633\\u0644\\u064a\\u0645": 76, "\\u0645\\u0631\\u0643\\u0632": 77, "\\u0627\\u0644\\u0639\\u062b\\u0648\\u0631": 78, "\\u0639\\u0644\\u0649": 79, "\\u0623\\u0645\\u0627\\u0643\\u0646": 80, "\\u0627\\u0644\\u0630\\u064a": 81, "\\u0644\\u0627": 82, "\\u062a\\u062f\\u0648\\u064a\\u0631\\u0647\\u061f": 83, "\\u0635\\u0646\\u0627\\u062f\\u064a\\u0642": 84, "\\u0627\\u0644\\u0628\\u064a\\u062a\\u0632\\u0627\\u061f": 85, "\\u0627\\u0644\\u0632\\u062c\\u0627\\u062c": 86, "\\u0627\\u0644\\u0645\\u0643\\u0633\\u0648\\u0631\\u061f": 87, "\\u0627\\u0644\\u0633\\u062a\\u064a\\u0631\\u0648\\u0641\\u0648\\u0645\\u061f": 88, "work": 89, "we": 90, "materials": 91, "happens": 92, "to": 93, "paper": 94, "after": 95, "process": 96, "they": 97, "benefits": 98, "of": 99, "important": 100, "help": 101, "environment": 102, "impact": 103, "have": 104, "properly": 105, "rules": 106, "any": 107, "guidelines": 108, "know": 109, "sort": 110, "my": 111, "drop": 112, "off": 113, "a": 114, "center": 115, "find": 116, "locations": 117, "can\'t": 118, "pizza": 119, "boxes": 120, "broken": 121, "styrofoam": 122}'}

# %%
vacab_size = len(tokenizer.word_index)
print('number of unique words = ', vacab_size)
vacab_size = 1000
# Out:
# number of unique words =  122

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

ptrn2seq = tokenizer.texts_to_sequences(df['patterns'])
X = pad_sequences(ptrn2seq, padding='post')
print('X shape = ', X.shape)

lbl_enc = LabelEncoder()
y = lbl_enc.fit_transform(df['tag'])
print('y shape = ', y.shape)
print('num of classes = ', len(np.unique(y)))
# Out:
# X shape =  (56, 9)
# y shape =  (56,)
# num of classes =  14

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Embedding, LSTM, LayerNormalization, Dense, Dropout

model = Sequential()
model.add(Input(shape=(X.shape[1],)))
model.add(Embedding(input_dim=vacab_size+1, output_dim=100))
model.add(LSTM(32, return_sequences=True))
model.add(LayerNormalization())
model.add(LSTM(32, return_sequences=True))
model.add(LayerNormalization())
model.add(LSTM(32))
model.add(LayerNormalization())
model.add(Dense(128, activation="relu"))
model.add(LayerNormalization())
model.add(Dropout(0.2))
model.add(Dense(len(np.unique(y)), activation="softmax"))
model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 9, 100)         │       100,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 9, 32)          │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization             │ (None, 9, 32)          │            64 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 9, 32)          │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_1           │ (None, 9, 32)          │            64 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_2           │ (None, 32)             │            64 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_3           │ (None, 128)            │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 14)             │         1,806 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 140,242 (547.82 KB)
#  Trainable params: 140,242 (547.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Split the data

# %%
model_history = model.fit(x=X,
                          y=y,
                          batch_size=10,
                          callbacks=[tensorflow.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)],
                          epochs=100)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.0429 - loss: 4.0446
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1514 - loss: 2.6213
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3418 - loss: 2.0844
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5024 - loss: 1.5890
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5464 - loss: 1.3205
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6282 - loss: 1.1913
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8526 - loss: 0.7919
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7971 - loss: 0.8897
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9329 - loss: 0.4854
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8932 - loss: 0.4648
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9555 - loss: 0.3638
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9487 - loss: 0.3295
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9623 - loss: 0.2929
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9623 - loss: 0.2236
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1523
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1594
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0881
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0947

# %% [markdown]
# #  Model Testing

# %% [markdown]
# #### First we should apply some text preprocessing on the pattern that is passed to the function. Next we convert the text to vector of numbers and give it to model for prediction its tag; Finally based on the tag, we choose a answer(response) randomly and return it.

# %%
import re
import random

def generate_answer(): 
    while True:
        pattern=input()
        text = []
        txt = re.sub('[^a-zA-Z\']', ' ', pattern)
        txt = txt.lower()
        txt = txt.split()
        txt = " ".join(txt)
        text.append(txt)

        x_test = tokenizer.texts_to_sequences(text)
        x_test = np.array(x_test).squeeze()
        x_test = pad_sequences([x_test], padding='post', maxlen=X.shape[1])
        y_pred = model.predict(x_test)
        y_pred = y_pred.argmax()
        tag = lbl_enc.inverse_transform([y_pred])[0]
        responses = df[df['tag'] == tag]['responses'].values[0]
        print("model: {}".format(random.choice(responses)))
        if pattern=='quite':
            break;

# %%
generate_answer()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# model: Check with your local program for more specific information on items that are not recyclable in your area.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# model: Recycling helps conserve natural resources, reduces pollution, and saves energy by reusing raw materials.
